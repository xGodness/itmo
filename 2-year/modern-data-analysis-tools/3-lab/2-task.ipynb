# %%
import matplotlib
import matplotlib.pyplot as plt
import torch

matplotlib.rcParams.update({"font.size": 14})

# %% [markdown]
# Create linear space and define function

# %%
x = torch.linspace(-30, 30, 500)
y = torch.sin(x) * x

# %% [markdown]
# Calculate differential and store values in `d_values`

# %%
d_values = []
for i in x:
    dx = i.clone().detach().requires_grad_(True)
    dy = torch.sin(dx) * dx
    dy.backward()
    d_values.append(dx.grad)

# %% [markdown]
# Draw the plot

# %%
plt.figure(figsize=(10, 10))
plt.plot(x, y, label="$f\\ (x) = sin(x) \\cdot x$", color="orange")
plt.plot(x, d_values, label="$\\frac{\\partial f}{\\partial x}$", color="blue")
plt.legend()
plt.xlabel("x")
plt.ylabel("y")
plt.grid(True)
plt.show()
